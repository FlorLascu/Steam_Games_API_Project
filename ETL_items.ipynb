# %% [markdown]
# # ETL User Items

# %%
import json
import os
import pandas as pd
import gzip
import ast
import numpy as np
import re
from datetime import datetime

# %%
rows = []

# Open the gzip-compressed JSON file
with gzip.open(r'C:\Users\flore\OneDrive\Escritorio\Etapa Labs\MLOPs\01. PI MLOps - STEAM\users_items.json.gz', 'rb') as f:
    # Iterate over each line in the file
    for line in f.readlines():
        # Decode the line and evaluate it as a Python literal
        rows.append(ast.literal_eval(line.decode('utf-8')))
        
# Convert the list of dictionaries into a DataFrame
df_items = pd.DataFrame(rows)

# Display the first few rows of the DataFrame
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
df_items.columns
# Out:
# Index(['user_id', 'items_count', 'steam_id', 'user_url', 'items'], dtype='object')

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# ### Check for duplicates
# Before me move into unnesting the column items, we check for duplicates in the column 'user_id'.

# %%
# Sort the DataFrame by 'user_id'
df_sorted = df_items.sort_values(by='user_id')

# Check for duplicate rows based on 'user_id' column
duplicated_rows = df_sorted[df_sorted.duplicated(subset=['user_id'], keep=False)]
duplicated_rows.head(20)
# Out:
#                      user_id  items_count           steam_id  \
# 29193               05041129           35  76561198167088451
# 11000               05041129           35  76561198167088451
# 37062         10outof10matee           56  76561198050688208
# 37061         10outof10matee           56  76561198050688208
# 6163   111222333444555666888           52  76561198082607692
# 6167   111222333444555666888           52  76561198082607692
# 29108              128bitbit           81  76561198061104290
# 29107              128bitbit           81  76561198061104290
# 19777               13272310           28  76561198087622450
# 19774               13272310           28  76561198087622450
# 2264              1337hunter           67  76561198100568975
# 28921             1337hunter           67  76561198100568975
# 8510                   29123           18  76561198075742344
# 8511                   29123           18  76561198075742344
# 10344                2greasy           33  76561198069153883
# 10346                2greasy           33  76561198069153883
# 8768            317984739321           75  76561198040364462
# 25214           317984739321           75  76561198040364462
# 5197                    4801           70  76561198095066558
# 5198                    4801           70  76561198095066558
#
#                                                 user_url  \
# 29193              http://steamcommunity.com/id/05041129
# 11000              http://steamcommunity.com/id/05041129
# 37062        http://steamcommunity.com/id/10outof10matee
# 37061        http://steamcommunity.com/id/10outof10matee
# 6163   http://steamcommunity.com/id/11122233344455566...
# 6167   http://steamcommunity.com/id/11122233344455566...
# 29108             http://steamcommunity.com/id/128bitbit
# 29107             http://steamcommunity.com/id/128bitbit
# 19777              http://steamcommunity.com/id/13272310
# 19774              http://steamcommunity.com/id/13272310
# 2264             http://steamcommunity.com/id/1337hunter
# 28921            http://steamcommunity.com/id/1337hunter
# 8510                  http://steamcommunity.com/id/29123
# 8511                  http://steamcommunity.com/id/29123
# 10344               http://steamcommunity.com/id/2greasy
# 10346               http://steamcommunity.com/id/2greasy
# 8768           http://steamcommunity.com/id/317984739321
# 25214          http://steamcommunity.com/id/317984739321
# 5197                   http://steamcommunity.com/id/4801
# 5198                   http://steamcommunity.com/id/4801
#
#                                                    items
# 29193  [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 11000  [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 37062  [{'item_id': '220', 'item_name': 'Half-Life 2'...
# 37061  [{'item_id': '220', 'item_name': 'Half-Life 2'...
# 6163   [{'item_id': '240', 'item_name': 'Counter-Stri...
# 6167   [{'item_id': '240', 'item_name': 'Counter-Stri...
# 29108  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 29107  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 19777  [{'item_id': '57690', 'item_name': 'Tropico 4'...
# 19774  [{'item_id': '57690', 'item_name': 'Tropico 4'...
# 2264   [{'item_id': '17470', 'item_name': 'Dead Space...
# 28921  [{'item_id': '17470', 'item_name': 'Dead Space...
# 8510   [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 8511   [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 10344  [{'item_id': '12200', 'item_name': 'Bully: Sch...
# 10346  [{'item_id': '12200', 'item_name': 'Bully: Sch...
# 8768   [{'item_id': '240', 'item_name': 'Counter-Stri...
# 25214  [{'item_id': '240', 'item_name': 'Counter-Stri...
# 5197   [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 5198   [{'item_id': '4000', 'item_name': 'Garry's Mod...

# %% [markdown]
# #### All of these registers: 1357 in total are clearly duplicated. So we will proceed to remove the duplicates and keep the first occurance<br>

# %%
# Drop duplicated rows based on 'user_id' and 'user_url' columns, keeping the first occurrence
df_items = df_items.drop_duplicates(subset=['user_id'], keep='first')

# Display the DataFrame after dropping duplicates
df_items
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 2                 http://steamcommunity.com/id/evcentric
# 3                http://steamcommunity.com/id/Riot-Punch
# 4                     http://steamcommunity.com/id/doctr
# ...                                                  ...
# 88305  http://steamcommunity.com/profiles/76561198323...
# 88306  http://steamcommunity.com/profiles/76561198326...
# 88307  http://steamcommunity.com/id/XxLaughingJackClo...
# 88308  http://steamcommunity.com/profiles/76561198329...
# 88309     http://steamcommunity.com/id/edward_tremethick
#
#                                                    items
# 0      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2      [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4      [{'item_id': '300', 'item_name': 'Day of Defea...
# ...                                                  ...
# 88305  [{'item_id': '413850', 'item_name': 'CS:GO Pla...
# 88306  [{'item_id': '11020', 'item_name': 'TrackMania...
# 88307                                                 []
# 88308  [{'item_id': '304930', 'item_name': 'Unturned'...
# 88309                                                 []
#
# [87626 rows x 5 columns]

# %%
df_items['user_id'].nunique()
# Out:
# 87626

# %% [markdown]
# ### This is the total amount of users in the platform

# %% [markdown]
# ### We review the last column, number 4, that has for each user_id the list of items owned by the user.

# %%
df_items.iloc[10,4]
# Out:
# [{'item_id': '4000',
#   'item_name': "Garry's Mod",
#   'playtime_forever': 2644,
#   'playtime_2weeks': 0},
#  {'item_id': '1250',
#   'item_name': 'Killing Floor',
#   'playtime_forever': 30266,
#   'playtime_2weeks': 0},
#  {'item_id': '35420',
#   'item_name': 'Killing Floor Mod: Defence Alliance 2',
#   'playtime_forever': 54,
#   'playtime_2weeks': 0},
#  {'item_id': '6060',
#   'item_name': 'STAR WARS™ Battlefront™ II',
#   'playtime_forever': 86,
#   'playtime_2weeks': 0},
#  {'item_id': '10',
#   'item_name': 'Counter-Strike',
#   'playtime_forever': 108,
#   'playtime_2weeks': 0},
#  {'item_id': '20',
#   'item_name': 'Team Fortress Classic',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '30',
#   'item_name': 'Day of Defeat',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '40',
#   'item_name': 'Deathmatch Classic',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '50',
#   'item_name': 'Half-Life: Opposing Force',
#   'playtime_forever': 45,
#   'playtime_2weeks': 0},
#  {'item_id': '60',
#   'item_name': 'Ricochet',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '70',
#   'item_name': 'Half-Life',
#   'playtime_forever': 227,
#   'playtime_2weeks': 0},
#  {'item_id': '80',
#   'item_name': 'Counter-Strike: Condition Zero',
#   'playtime_forever': 245,
#   'playtime_2weeks': 0},
#  {'item_id': '100',
#   'item_name': 'Counter-Strike: Condition Zero Deleted Scenes',
#   'playtime_forever': 37,
#   'playtime_2weeks': 0},
#  {'item_id': '130',
#   'item_name': 'Half-Life: Blue Shift',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '220',
#   'item_name': 'Half-Life 2',
#   'playtime_forever': 736,
#   'playtime_2weeks': 0},
#  {'item_id': '240',
#   'item_name': 'Counter-Strike: Source',
#   'playtime_forever': 63940,
#   'playtime_2weeks': 0},
#  {'item_id': '280',
#   'item_name': 'Half-Life: Source',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '300',
#   'item_name': 'Day of Defeat: Source',
#   'playtime_forever': 248,
#   'playtime_2weeks': 0},
#  {'item_id': '320',
#   'item_name': 'Half-Life 2: Deathmatch',
#   'playtime_forever': 173,
#   'playtime_2weeks': 0},
#  {'item_id': '340',
#   'item_name': 'Half-Life 2: Lost Coast',
#   'playtime_forever': 33,
#   'playtime_2weeks': 0},
#  {'item_id': '360',
#   'item_name': 'Half-Life Deathmatch: Source',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '380',
#   'item_name': 'Half-Life 2: Episode One',
#   'playtime_forever': 199,
#   'playtime_2weeks': 0},
#  {'item_id': '400',
#   'item_name': 'Portal',
#   'playtime_forever': 238,
#   'playtime_2weeks': 0},
#  {'item_id': '420',
#   'item_name': 'Half-Life 2: Episode Two',
#   'playtime_forever': 281,
#   'playtime_2weeks': 0},
#  {'item_id': '500',
#   'item_name': 'Left 4 Dead',
#   'playtime_forever': 2524,
#   'playtime_2weeks': 0},
#  {'item_id': '550',
#   'item_name': 'Left 4 Dead 2',
#   'playtime_forever': 12908,
#   'playtime_2weeks': 0},
#  {'item_id': '223530',
#   'item_name': 'Left 4 Dead 2 Beta',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '10680',
#   'item_name': 'Aliens vs. Predator',
#   'playtime_forever': 1031,
#   'playtime_2weeks': 0},
#  {'item_id': '24960',
#   'item_name': 'Battlefield: Bad Company 2',
#   'playtime_forever': 501,
#   'playtime_2weeks': 0},
#  {'item_id': '43000',
#   'item_name': 'Front Mission Evolved',
#   'playtime_forever': 784,
#   'playtime_2weeks': 0},
#  {'item_id': '8980',
#   'item_name': 'Borderlands',
#   'playtime_forever': 5002,
#   'playtime_2weeks': 0},
#  {'item_id': '42700',
#   'item_name': 'Call of Duty: Black Ops',
#   'playtime_forever': 1440,
#   'playtime_2weeks': 0},
#  {'item_id': '42710',
#   'item_name': 'Call of Duty: Black Ops - Multiplayer',
#   'playtime_forever': 39,
#   'playtime_2weeks': 0},
#  {'item_id': '63200',
#   'item_name': 'Monday Night Combat',
#   'playtime_forever': 1227,
#   'playtime_2weeks': 0},
#  {'item_id': '15750',
#   'item_name': "Oddworld: Stranger's Wrath HD",
#   'playtime_forever': 872,
#   'playtime_2weeks': 0},
#  {'item_id': '42910',
#   'item_name': 'Magicka',
#   'playtime_forever': 236,
#   'playtime_2weeks': 0},
#  {'item_id': '620',
#   'item_name': 'Portal 2',
#   'playtime_forever': 3244,
#   'playtime_2weeks': 0},
#  {'item_id': '12900',
#   'item_name': 'Audiosurf',
#   'playtime_forever': 16,
#   'playtime_2weeks': 0},
#  {'item_id': '15500',
#   'item_name': 'The Wonderful End of the World',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '15520',
#   'item_name': 'AaAaAA!!! - A Reckless Disregard for Gravity',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '15540',
#   'item_name': '1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '18500',
#   'item_name': 'Defense Grid: The Awakening',
#   'playtime_forever': 210,
#   'playtime_2weeks': 0},
#  {'item_id': '26500',
#   'item_name': 'Cogs',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '35460',
#   'item_name': 'The Ball',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '38700',
#   'item_name': 'Toki Tori',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '38720',
#   'item_name': 'RUSH',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '40800',
#   'item_name': 'Super Meat Boy',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '57300',
#   'item_name': 'Amnesia: The Dark Descent',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '63700',
#   'item_name': 'BIT.TRIP BEAT',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '105600',
#   'item_name': 'Terraria',
#   'playtime_forever': 7891,
#   'playtime_2weeks': 0},
#  {'item_id': '105400',
#   'item_name': 'Fable III',
#   'playtime_forever': 991,
#   'playtime_2weeks': 0},
#  {'item_id': '24240',
#   'item_name': 'PAYDAY: The Heist',
#   'playtime_forever': 1346,
#   'playtime_2weeks': 0},
#  {'item_id': '17710',
#   'item_name': 'Nuclear Dawn',
#   'playtime_forever': 1506,
#   'playtime_2weeks': 0},
#  {'item_id': '104900',
#   'item_name': 'ORION: Prelude',
#   'playtime_forever': 991,
#   'playtime_2weeks': 0},
#  {'item_id': '3700',
#   'item_name': 'Sniper Elite',
#   'playtime_forever': 23,
#   'playtime_2weeks': 0},
#  {'item_id': '63380',
#   'item_name': 'Sniper Elite V2',
#   'playtime_forever': 839,
#   'playtime_2weeks': 0},
#  {'item_id': '49520',
#   'item_name': 'Borderlands 2',
#   'playtime_forever': 5368,
#   'playtime_2weeks': 0},
#  {'item_id': '730',
#   'item_name': 'Counter-Strike: Global Offensive',
#   'playtime_forever': 9373,
#   'playtime_2weeks': 0},
#  {'item_id': '216390',
#   'item_name': 'Fallen Enchantress',
#   'playtime_forever': 2651,
#   'playtime_2weeks': 0},
#  {'item_id': '205950',
#   'item_name': 'Jet Set Radio',
#   'playtime_forever': 46,
#   'playtime_2weeks': 0},
#  {'item_id': '200710',
#   'item_name': 'Torchlight II',
#   'playtime_forever': 1614,
#   'playtime_2weeks': 0},
#  {'item_id': '205790',
#   'item_name': 'Dota 2 Test',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '219640',
#   'item_name': 'Chivalry: Medieval Warfare',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '232210',
#   'item_name': 'Patch testing for Chivalry',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '4920',
#   'item_name': 'Natural Selection 2',
#   'playtime_forever': 125,
#   'playtime_2weeks': 0},
#  {'item_id': '55230',
#   'item_name': 'Saints Row: The Third',
#   'playtime_forever': 2369,
#   'playtime_2weeks': 0},
#  {'item_id': '202970',
#   'item_name': 'Call of Duty: Black Ops II',
#   'playtime_forever': 3,
#   'playtime_2weeks': 0},
#  {'item_id': '202990',
#   'item_name': 'Call of Duty: Black Ops II - Multiplayer',
#   'playtime_forever': 1551,
#   'playtime_2weeks': 0},
#  {'item_id': '212910',
#   'item_name': 'Call of Duty: Black Ops II - Zombies',
#   'playtime_forever': 10678,
#   'playtime_2weeks': 329},
#  {'item_id': '213610',
#   'item_name': 'Sonic Adventure™ 2 ',
#   'playtime_forever': 168,
#   'playtime_2weeks': 0},
#  {'item_id': '102600',
#   'item_name': 'Orcs Must Die!',
#   'playtime_forever': 336,
#   'playtime_2weeks': 0},
#  {'item_id': '201790',
#   'item_name': 'Orcs Must Die! 2',
#   'playtime_forever': 3425,
#   'playtime_2weeks': 0},
#  {'item_id': '224540',
#   'item_name': 'Ace of Spades',
#   'playtime_forever': 143,
#   'playtime_2weeks': 0},
#  {'item_id': '36630',
#   'item_name': 'Rusty Hearts',
#   'playtime_forever': 1742,
#   'playtime_2weeks': 0},
#  {'item_id': '99900',
#   'item_name': 'Spiral Knights',
#   'playtime_forever': 1026,
#   'playtime_2weeks': 0},
#  {'item_id': '102700',
#   'item_name': 'A.V.A - Alliance of Valiant Arms',
#   'playtime_forever': 3467,
#   'playtime_2weeks': 0},
#  {'item_id': '208090',
#   'item_name': 'Loadout',
#   'playtime_forever': 2409,
#   'playtime_2weeks': 0},
#  {'item_id': '230410',
#   'item_name': 'Warframe',
#   'playtime_forever': 5781,
#   'playtime_2weeks': 0},
#  {'item_id': '234310',
#   'item_name': 'March of War',
#   'playtime_forever': 3225,
#   'playtime_2weeks': 0},
#  {'item_id': '243870',
#   'item_name': "Tom Clancy's Ghost Recon Phantoms - NA",
#   'playtime_forever': 1472,
#   'playtime_2weeks': 0},
#  {'item_id': '209870',
#   'item_name': 'Blacklight: Retribution',
#   'playtime_forever': 5828,
#   'playtime_2weeks': 0},
#  {'item_id': '271290',
#   'item_name': 'HAWKEN',
#   'playtime_forever': 2223,
#   'playtime_2weeks': 0},
#  {'item_id': '291150',
#   'item_name': 'Evolution RTS',
#   'playtime_forever': 153,
#   'playtime_2weeks': 0},
#  {'item_id': '224260',
#   'item_name': 'No More Room in Hell',
#   'playtime_forever': 683,
#   'playtime_2weeks': 0},
#  {'item_id': '224580',
#   'item_name': 'Arma 2: DayZ Mod',
#   'playtime_forever': 13,
#   'playtime_2weeks': 0},
#  {'item_id': '33900',
#   'item_name': 'Arma 2',
#   'playtime_forever': 8,
#   'playtime_2weeks': 0},
#  {'item_id': '33930',
#   'item_name': 'Arma 2: Operation Arrowhead',
#   'playtime_forever': 10,
#   'playtime_2weeks': 0},
#  {'item_id': '65700',
#   'item_name': 'Arma 2: British Armed Forces',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '65720',
#   'item_name': 'Arma 2: Private Military Company',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '219540',
#   'item_name': 'Arma 2: Operation Arrowhead Beta (Obsolete)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '227680',
#   'item_name': 'StarForge',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '218620',
#   'item_name': 'PAYDAY 2',
#   'playtime_forever': 18497,
#   'playtime_2weeks': 0},
#  {'item_id': '35720',
#   'item_name': 'Trine 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '91310',
#   'item_name': 'Dead Island',
#   'playtime_forever': 858,
#   'playtime_2weeks': 0},
#  {'item_id': '216250',
#   'item_name': 'Dead Island Riptide',
#   'playtime_forever': 985,
#   'playtime_2weeks': 0},
#  {'item_id': '206420',
#   'item_name': 'Saints Row IV',
#   'playtime_forever': 3876,
#   'playtime_2weeks': 0},
#  {'item_id': '249130',
#   'item_name': 'LEGO® MARVEL Super Heroes',
#   'playtime_forever': 1435,
#   'playtime_2weeks': 0},
#  {'item_id': '239160',
#   'item_name': 'Thief',
#   'playtime_forever': 2727,
#   'playtime_2weeks': 0},
#  {'item_id': '243470',
#   'item_name': 'Watch_Dogs',
#   'playtime_forever': 1555,
#   'playtime_2weeks': 0},
#  {'item_id': '238430',
#   'item_name': 'Contagion',
#   'playtime_forever': 278,
#   'playtime_2weeks': 0},
#  {'item_id': '209160',
#   'item_name': 'Call of Duty: Ghosts',
#   'playtime_forever': 423,
#   'playtime_2weeks': 0},
#  {'item_id': '209170',
#   'item_name': 'Call of Duty: Ghosts - Multiplayer',
#   'playtime_forever': 8841,
#   'playtime_2weeks': 187},
#  {'item_id': '211820',
#   'item_name': 'Starbound',
#   'playtime_forever': 853,
#   'playtime_2weeks': 0},
#  {'item_id': '367540',
#   'item_name': 'Starbound - Unstable',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '273110',
#   'item_name': 'Counter-Strike Nexon: Zombies',
#   'playtime_forever': 813,
#   'playtime_2weeks': 0},
#  {'item_id': '222880',
#   'item_name': 'Insurgency',
#   'playtime_forever': 13029,
#   'playtime_2weeks': 0},
#  {'item_id': '222900',
#   'item_name': 'Dead Island: Epidemic',
#   'playtime_forever': 591,
#   'playtime_2weeks': 0},
#  {'item_id': '291480',
#   'item_name': 'Warface',
#   'playtime_forever': 19576,
#   'playtime_2weeks': 216},
#  {'item_id': '238590',
#   'item_name': 'Loadout Campaign Beta',
#   'playtime_forever': 506,
#   'playtime_2weeks': 0},
#  {'item_id': '326960',
#   'item_name': 'Killing Floor - Toy Master',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '232090',
#   'item_name': 'Killing Floor 2',
#   'playtime_forever': 17364,
#   'playtime_2weeks': 275},
#  {'item_id': '232150',
#   'item_name': 'Killing Floor 2 - SDK',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '369200',
#   'item_name': 'Ghost in the Shell Stand Alone Complex First Assault Online',
#   'playtime_forever': 539,
#   'playtime_2weeks': 0},
#  {'item_id': '444090',
#   'item_name': 'Paladins',
#   'playtime_forever': 462,
#   'playtime_2weeks': 462},
#  {'item_id': '444640',
#   'item_name': 'Bloons TD Battles',
#   'playtime_forever': 809,
#   'playtime_2weeks': 0}]

# %% [markdown]
# #### In order to make this information useful we need to convert the information contain in the column into columns item_id, item_name, playtime_forever, ply time_2weeks.

# %%
# unnest the json objects in the column items
items_des = []

for index, row in df_items.iterrows():
    user_id = row['user_id']
    items_count = row['items_count']
    steam_id = row['steam_id']
    user_url = row['user_url']
    items = row['items']
    
    for i in items:   
        new_row = {
        'user_id': user_id,
        'items_count': items_count,
        'steam_id' : steam_id,
        'user_url' : user_url,
        'item_id': i.get('item_id', ''),
        'item_name': i.get('item_name', ''),
        'playtime_forever': i.get('playtime_forever', ''),
        'playtime_2weeks': i.get('playtime_2weeks', '')
        }
        
        items_des.append(new_row)

df_items_unnested = pd.DataFrame(items_des)

# %%
df_items_unnested.head(4)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1  76561197970982479          277  76561197970982479
# 2  76561197970982479          277  76561197970982479
# 3  76561197970982479          277  76561197970982479
#
#                                             user_url item_id  \
# 0  http://steamcommunity.com/profiles/76561197970...      10
# 1  http://steamcommunity.com/profiles/76561197970...      20
# 2  http://steamcommunity.com/profiles/76561197970...      30
# 3  http://steamcommunity.com/profiles/76561197970...      40
#
#                item_name  playtime_forever  playtime_2weeks
# 0         Counter-Strike                 6                0
# 1  Team Fortress Classic                 0                0
# 2          Day of Defeat                 7                0
# 3     Deathmatch Classic                 0                0

# %%
df_items_unnested.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5094082 entries, 0 to 5094081
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   steam_id          object
#  3   user_url          object
#  4   item_id           object
#  5   item_name         object
#  6   playtime_forever  int64
#  7   playtime_2weeks   int64
# dtypes: int64(3), object(5)
# memory usage: 310.9+ MB

# %%
df_items = df_items_unnested

# %%
# Count the number of missing values in each column
missing_count = df_items.isna().sum()
# Calculate the percentae of missing values for each column
missing_percentage = (missing_count / len(df_items)) * 100
# Combine the missing cont and percentage into a DataFrame
missing_info = pd.DataFrame({'Missing Count': missing_count, 'Missing Percentage': missing_percentage})
# Add a new column for the total number of rows in the DataFrame
missing_info['Total Registers'] = len(df_items)
# Reorder columns
missing_info = missing_info[['Total Registers', 'Missing Count', 'Missing Percentage']]
# Display the missing information
missing_info
# Out:
#                   Total Registers  Missing Count  Missing Percentage
# user_id                   5094082              0                 0.0
# items_count               5094082              0                 0.0
# steam_id                  5094082              0                 0.0
# user_url                  5094082              0                 0.0
# item_id                   5094082              0                 0.0
# item_name                 5094082              0                 0.0
# playtime_forever          5094082              0                 0.0
# playtime_2weeks           5094082              0                 0.0

# %% [markdown]
# ### Valuable information and disposable data
# Now that we have some insight into the dataframe structure and information we can conclude that there are many columns we can drop in order to keep our data manageable and as compact as possible<br>
# #### Columns to drop:<br>
# -   **items_count** is a column that given the information can be calculated by request<br>
# -   **steam_id** is the same exact value as **user_id**
# -   **user_url** it is already contained in the review dataframe so in case it is needed it can be then pulled from that dataframe by request<br>

# %%
df_items.drop(['items_count','steam_id','user_url'], axis=1, inplace= True)

# %% [markdown]
# ### Correct datatypes for columns 'user_id' and ' item_id'

# %%
df_items["item_id"] = pd.to_numeric(df_items["item_id"], errors="coerce")

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5094082 entries, 0 to 5094081
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   item_id           int64
#  2   item_name         object
#  3   playtime_forever  int64
#  4   playtime_2weeks   int64
# dtypes: int64(3), object(2)
# memory usage: 194.3+ MB

# %% [markdown]
# ### Store items Dataframe
# Now that we have done the load and transformation of the data into a valueable information we store it to proceed with the EDA.
# We choose to store the data as .parquet beacuse of the size limitations<br>

# %%
# Define the file path for storing the Parquet file
items = 'data/items.parquet'

# Store the DataFrame as a Parquet file
df_items.to_parquet(items, index=False)

# Print a message confirming the storage location
print(f'Items DataFrame was stored into {items}')
# Out:
# Items DataFrame was stored into data/items.parquet
